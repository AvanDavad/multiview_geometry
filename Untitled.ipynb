# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
from multiview_geometry.proj2D import get_line_points_xy

# %%
np.set_printoptions(suppress=True, precision=4)

# %%
plt.figure(figsize=(8,8))

plt.scatter([1.1966,-1.005,-0.9993,1.0081], [0.429, 0.5206, -0.4863, -0.5431])

line1 = np.array([0.0355, 0.9994, -0.4779])
x1, y1 = get_line_points_xy(line1)
plt.plot(x1, y1)

line2 = np.array([-0.9959, 0.0908, -1.0011])
x2, y2 = get_line_points_xy(line2)
plt.plot(x2, y2)

line3 = np.array([0.0355, 0.9994, 0.5142])
x3, y3 = get_line_points_xy(line3)
plt.plot(x3, y3)

line4 = np.array([-0.9959, 0.0908, 1.1046])
x4, y4 = get_line_points_xy(line4)
plt.plot(x4, y4)

plt.xlim(-2, 2)
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)
