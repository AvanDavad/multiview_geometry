# %%
import numpy as np
np.set_printoptions(suppress=True, precision=4)

# %%
import matplotlib.pyplot as plt

# %%
from multiview_geometry import proj2D
from multiview_geometry import utils

# %%
line = np.array([0.1, 1.0, 0.])
p1, p2 = proj2D.get_line_points(line)
p1ih = utils.from_hom(p1)
p2ih = utils.from_hom(p2)

plt.figure(figsize=(6,6))

plt.plot([p1ih[0], p2ih[0]], [p1ih[1], p2ih[1]])

plt.xlim(-3, 3)
plt.ylim(-3, 3)
# Out:
# (-3.0, 3.0)
